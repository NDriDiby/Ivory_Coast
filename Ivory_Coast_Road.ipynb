# %%
#libary
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print("I'm Ready to go")
# Out:
# I'm Ready to go

# %%
#Import data set
df = pd.read_csv("/Users/pm3796gb/Desktop/Nova Cloud /ci_data_road.csv")

# %%
df.head()
# Out:
#    UNIFORM_ID           ADM2_NAME  ADM2_ID  ADM3_NAME  ADM3_ID  ROAD_ID  \
# 0           1              AGNEBY        1     ADZOPE        4        8
# 1           2  DIX-HUIT MONTAGNES        6    BANGOLO        7       73
# 2           3  DIX-HUIT MONTAGNES        6    BANGOLO        7       73
# 3           4              ZANZAN       19  BONDOUKOU       10       75
# 4           5            DENGUELE        5    ODIENNE       34       77
#
#   ROAD_NAME START_NODE     END_NODE                 LINK_NAME  ...  LOCAL_CLS  \
# 0       N16    Boudepé         Agou          N16.Boudepé-Agou  ...          1
# 1      N264    Kouibli     jct_N264     N264.Kouibli-jct_N264  ...          2
# 2      N264    jct_D13      jct_D12      N264.jct_D13-jct_D12  ...          2
# 3      N266   jct_D120      jct_N12     N266.jct_D120-jct_N12  ...          2
# 4      N268    jct_D11  Dzéguétiéla  N268.jct_D11-Dzéguétiéla  ...          2
#
# ...

# %%
df =df.rename(columns={'ADM2_NAME':"Region"})
df=df.rename(columns={"ROAD_COND_VALUE":"Condition"})
df=df.rename(columns={"ADM3_NAME":"Town"})

# %%
df.head()
# Out:
#    UNIFORM_ID              Region  ADM2_ID       Town  ADM3_ID  ROAD_ID  \
# 0           1              AGNEBY        1     ADZOPE        4        8
# 1           2  DIX-HUIT MONTAGNES        6    BANGOLO        7       73
# 2           3  DIX-HUIT MONTAGNES        6    BANGOLO        7       73
# 3           4              ZANZAN       19  BONDOUKOU       10       75
# 4           5            DENGUELE        5    ODIENNE       34       77
#
#   ROAD_NAME START_NODE     END_NODE                 LINK_NAME  ...  LOCAL_CLS  \
# 0       N16    Boudepé         Agou          N16.Boudepé-Agou  ...          1
# 1      N264    Kouibli     jct_N264     N264.Kouibli-jct_N264  ...          2
# 2      N264    jct_D13      jct_D12      N264.jct_D13-jct_D12  ...          2
# 3      N266   jct_D120      jct_N12     N266.jct_D120-jct_N12  ...          2
# 4      N268    jct_D11  Dzéguétiéla  N268.jct_D11-Dzéguétiéla  ...          2
#
# ...

# %%
df.shape
# Out:
# (2053, 21)

# %%
df.describe()
# Out:
#         UNIFORM_ID      ADM2_ID     ADM3_ID      ROAD_ID      RD_TYPE  \
# count  2053.000000  2053.000000  2053.00000  2053.000000  2053.000000
# mean   1027.000000    11.287384    25.09888    80.136873     2.215295
# std     592.794371     5.421082    14.18145    64.388526     0.796202
# min       1.000000     1.000000     1.00000   -99.000000     1.000000
# 25%     514.000000     6.000000    13.00000    14.000000     2.000000
# 50%    1027.000000    13.000000    25.00000    70.000000     2.000000
# 75%    1540.000000    16.000000    36.00000   141.000000     3.000000
# max    2053.000000    19.000000    50.00000   196.000000     3.000000
#
#          LOCAL_CLS       LENGTH   ROAD_WIDTH    AADT_CODE  SURF_TYPE_CODE  \
# count  2053.000000  2053.000000  2053.000000  2053.000000     2053.000000
# mean      1.927910    12.449009     7.166098   -46.483682        4.407209
# std       5.050299     8.188538     0.573480    51.547810        1.065033
# ...

# %%
df.set_index("Region")
# Out:
#                     UNIFORM_ID  ADM2_ID            Town  ADM3_ID  ROAD_ID  \
# Region
# AGNEBY                       1        1          ADZOPE        4        8
# DIX-HUIT MONTAGNES           2        6         BANGOLO        7       73
# DIX-HUIT MONTAGNES           3        6         BANGOLO        7       73
# ZANZAN                       4       19       BONDOUKOU       10       75
# DENGUELE                     5        5         ODIENNE       34       77
# DENGUELE                     6        5         ODIENNE       34       78
# NZI-COMOE                    7       13      M'BAHIAKRO       33       99
# SUD-COMOE                    8       16         ABOISSO        3       86
# SUD-COMOE                    9       16         ABOISSO        3       86
# SUD-COMOE                   10       16         ABOISSO        3       88
# SUD-BANDAMA                 11       15            DIVO       21        2
# BAS-SASSANDRA               12        3       SASSANDRA       38        2
# ...

# %%
plt.figure(figsize=(15,7))
df.groupby("Town")["Condition"].count().plot(kind='bar')

# %%
plt.figure(figsize=(15,7))
df.groupby("Region")["Condition"].count().plot(kind='bar')

# %%
plt.figure(figsize=(15,7))
df.groupby('Region')['LENGTH'].mean().sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
df.groupby('Town')['LENGTH'].mean().sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,7))
df.groupby('Condition')['LENGTH','ROAD_WIDTH'].mean().plot(kind='barh',figsize=(15,7))

# %%
plt.figure(figsize=(15,7))
df.groupby('Region')['ROAD_WIDTH'].mean().sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
df.groupby('Town')['ROAD_WIDTH'].mean().sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
df.groupby('Town')['LANE_NB'].mean().sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
df.groupby('Region')['LANE_NB','ROAD_WIDTH'].mean().plot(kind='bar',figsize=(15,10))

# %%
plt.figure(figsize=(15,10))
df.groupby('SURF_TYPE_VALUE')['LANE_NB','ROAD_WIDTH'].mean().plot(kind='barh',figsize=(15,10))

# %%
plt.figure(figsize=(15,10))
df.groupby('SOURCE')['Condition'].count().plot(kind='barh',figsize=(15,10))

# %%
df.groupby("SURF_TYPE_VALUE")['Condition'].count()
# Out:
# SURF_TYPE_VALUE
# Asphalt               205
# Earth                1547
# Surface Treatment     301
# Name: Condition, dtype: int64

# %%
plt.
